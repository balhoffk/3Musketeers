# %%
#Documents to be able to use keys across different baseball websites
#Team key below, aggregates different spellings of team names, different team IDs across different baseball websites
import pandas as pd
from sqlalchemy import create_engine

# %%
file = 'SFBB MLB Team Map - SFBB Team Map.csv'
team_df = pd.read_csv(file)

# %%
team_df.head()
# Out:
#   SFBBTEAM FDTEAM DKTEAM BBREFTEAM YAHOOTEAM FANPROSTEAM BASEBALLPRESSTEAM  \
# 0      ARI    ARI    ARI       ARI       ARI         ARI               ARI
# 1      ATL    ATL    ATL       ATL       ATL         ATL               ATL
# 2      BAL    BAL    BAL       BAL       BAL         BAL               BAL
# 3      BOS    BOS    BOS       BOS       BOS         BOS               BOS
# 4      CHC    CHC    CHC       CHC       CHC         CHC               CHC
#
#   FANGRAPHSTEAM ESPNTEAM BPTEAM ROTOWIRETEAM         ROSTERRESOURCEURL  \
# 0  Diamondbacks      ARI    ARI          ARI  MLB-ARIZONA-DIAMONDBACKS
# 1        Braves      ATL    ATL          ATL        MLB-ATLANTA-BRAVES
# 2       Orioles      BAL    BAL          BAL     MLB-BALTIMORE-ORIOLES
# 3       Red Sox      BOS    BOS          BOS        MLB-BOSTON-RED-SOX
# 4          Cubs      CHC    CHN          CHC          MLB-CHICAGO-CUBS
#
#          ROSTERTEAMNAME            ROSTERTEAM          ROSTERPROPER  \
# ...

# %%
BBREF_df = team_df[['BBREFTEAM', 'ROSTERPROPERVALUE']].copy()
BBREF_df.head()
# Out:
#   BBREFTEAM     ROSTERPROPERVALUE
# 0       ARI  Arizona Diamondbacks
# 1       ATL        Atlanta Braves
# 2       BAL     Baltimore Orioles
# 3       BOS        Boston Red Sox
# 4       CHC          Chicago Cubs

# %%
BBREF_df = BBREF_df.rename(columns = {'BBREFTEAM':'bbrefteam', 'ROSTERPROPERVALUE':'rosterpropervalue'})
BBREF_df
# Out:
#    bbrefteam      rosterpropervalue
# 0        ARI   Arizona Diamondbacks
# 1        ATL         Atlanta Braves
# 2        BAL      Baltimore Orioles
# 3        BOS         Boston Red Sox
# 4        CHC           Chicago Cubs
# 5        CHW      Chicago White Sox
# 6        CIN        Cincinnati Reds
# 7        CLE      Cleveland Indians
# 8        COL       Colorado Rockies
# 9        DET         Detroit Tigers
# 10       HOU         Houston Astros
# 11       KCR     Kansas City Royals
# 12       LAA     Los Angeles Angels
# 13       LAD    Los Angeles Dodgers
# 14       MIA          Miami Marlins
# 15       MIL      Milwaukee Brewers
# 16       MIN        Minnesota Twins
# 17       NYM          New York Mets
# 18       NYY       New York Yankees
# 19       OAK      Oakland Athletics
# 20       PHI  Philadelphia Phillies
# 21       PIT     Pittsburgh Pirates
# 22       SDP       San Diego Padres
# 23       SEA       Seattle Mariners
# 24       SFG   San Francisco Giants
# ...

# %%
attendance_file = 'baseballdata.csv'
attendance_df = pd.read_csv(attendance_file)
new_attendance_df = attendance_df[['Tm', 'Attendance', "Year"]].copy()
new_attendance_df


## attendance_df.rename(columns={"Team ID": "TEAM", "Team Name" : "Team_name"})
# Out:
#                        Tm Attendance  Year
# 0    Arizona Diamondbacks  2,036,216  2016
# 1    Arizona Diamondbacks  2,080,145  2015
# 2    Arizona Diamondbacks  2,073,730  2014
# 3    Arizona Diamondbacks  2,134,895  2013
# 4    Arizona Diamondbacks  2,177,617  2012
# ..                    ...        ...   ...
# 355  Washington Nationals  1,817,226  2009
# 356  Washington Nationals  2,320,400  2008
# 357  Washington Nationals  1,943,812  2007
# 358  Washington Nationals  2,153,056  2006
# 359  Washington Nationals  2,731,993  2005
#
# [360 rows x 3 columns]

# %%
new2015_df = new_attendance_df[new_attendance_df['Year'] == 2015]

# %%
new2015_df
# Out:
#                                 Tm Attendance  Year
# 1             Arizona Diamondbacks  2,080,145  2015
# 13                  Atlanta Braves  2,001,392  2015
# 25               Baltimore Orioles  2,281,202  2015
# 37                  Boston Red Sox  2,880,694  2015
# 49                    Chicago Cubs  2,919,122  2015
# 61               Chicago White Sox  1,755,810  2015
# 73                 Cincinnati Reds  2,419,506  2015
# 85               Cleveland Indians  1,388,905  2015
# 97                Colorado Rockies  2,506,789  2015
# 109                 Detroit Tigers  2,726,048  2015
# 121                 Houston Astros  2,153,585  2015
# 133             Kansas City Royals  2,708,549  2015
# 145  Los Angeles Angels of Anaheim  3,012,765  2015
# 157            Los Angeles Dodgers  3,764,815  2015
# 169                  Miami Marlins  1,752,235  2015
# 181              Milwaukee Brewers  2,542,558  2015
# 193                Minnesota Twins  2,220,054  2015
# ...

# %%
new2015_df = new2015_df.rename(columns = {'Tm':'tm', 'Attendance':'attendance','Year':'year'})
new2015_df
# Out:
#                                 tm attendance  year
# 1             Arizona Diamondbacks  2,080,145  2015
# 13                  Atlanta Braves  2,001,392  2015
# 25               Baltimore Orioles  2,281,202  2015
# 37                  Boston Red Sox  2,880,694  2015
# 49                    Chicago Cubs  2,919,122  2015
# 61               Chicago White Sox  1,755,810  2015
# 73                 Cincinnati Reds  2,419,506  2015
# 85               Cleveland Indians  1,388,905  2015
# 97                Colorado Rockies  2,506,789  2015
# 109                 Detroit Tigers  2,726,048  2015
# 121                 Houston Astros  2,153,585  2015
# 133             Kansas City Royals  2,708,549  2015
# 145  Los Angeles Angels of Anaheim  3,012,765  2015
# 157            Los Angeles Dodgers  3,764,815  2015
# 169                  Miami Marlins  1,752,235  2015
# 181              Milwaukee Brewers  2,542,558  2015
# 193                Minnesota Twins  2,220,054  2015
# ...

# %%
batting_file = "2015batting.csv"
batting_df = pd.read_csv(batting_file)
new_batting_df = batting_df[['Tm', 'BA', 'OBP', 'SB', 'HR']].copy()
new_batting_df = new_batting_df.rename(columns = {'Tm':'team', 'BA':'battingavg','OBP':'onbasepercent', 'SB':'stolenbases', 'HR': 'homeruns'})
#dropping null values for league average
new_batting_df= new_batting_df.drop([30,31])
new_batting_df
# Out:
#    team  battingavg  onbasepercent  stolenbases  homeruns
# 0   ARI       0.264          0.324          132       154
# 1   ATL       0.251          0.314           69       100
# 2   BAL       0.250          0.307           44       217
# 3   BOS       0.265          0.325           71       161
# 4   CHC       0.244          0.321           95       171
# 5   CHW       0.250          0.306           68       136
# 6   CIN       0.248          0.312          134       167
# 7   CLE       0.256          0.325           86       141
# 8   COL       0.265          0.315           97       186
# 9   DET       0.270          0.328           83       151
# 10  HOU       0.250          0.315          121       230
# 11  KCR       0.269          0.322          104       139
# 12  LAA       0.246          0.307           52       176
# 13  LAD       0.250          0.326           59       187
# 14  MIA       0.260          0.310          112       120
# ...

# %%
#loading df into MLB SQL file
username = "postgres"
password = "postgres"
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/MLB')

# %%
#checking for table names
engine.table_names()
# Out:
# ['teamkeys', 'attendance', 'fifteen_batting']

# %%
new_batting_df.to_sql(name='fifteen_batting', con=engine, if_exists='append', index=False)

# %%
new2015_df.to_sql(name='attendance', con=engine, if_exists='append', index=False)

# %%
BBREF_df.to_sql(name='teamkeys', con=engine, if_exists='append', index=False)
